# %% [markdown]
# # <center>CLEAN WATER AND SANITATION</center>
# <center><img src= "https://cdn.imweb.me/upload/S202108243f92708905182/b551dffc90f4f.jpg" alt ="Titanic" style='width:500px;'></center><br>

# %% [markdown]
# Clean water and sanitation are essential for promoting public health and ensuring the well-being of communities worldwide. Access to clean water is a fundamental human right, yet millions of people around the world lack access to safe drinking water and basic sanitation facilities. Lack of access to clean water and sanitation is a major cause of disease, particularly in low-income countries, where inadequate infrastructure and poor hygiene practices contribute to the spread of waterborne illnesses. Ensuring access to clean water and sanitation is critical for reducing mortality rates, improving overall health outcomes, and promoting economic development. Effective water and sanitation management requires a combination of infrastructure development, public education, and policy reforms, as well as innovative technologies such as machine learning to improve water quality and optimize treatment processes. Addressing the challenges of clean water and sanitation is essential for achieving sustainable development goals and promoting global health and well-being.

# %% [markdown]
# ## What is sanitation ?
#
# Sanitation refers to the measures taken to promote and preserve public health by preventing the spread of diseases through various forms of environmental controls, such as the treatment and disposal of sewage and waste, the provision of clean water and hygiene facilities, and the promotion of good hygiene practices. Sanitation is a critical aspect of public health and is essential for preventing the spread of infectious diseases, reducing child mortality rates, and improving the overall quality of life for individuals and communities.

# %% [markdown]
# ## Objective

# %% [markdown]
# Which regions have improved in these 20 years to what extent have the investments made had an impact? Likewise, a study on clean water. Like a report document.

# %% [markdown]
# ## About Dataset

# %% [markdown]
# Dataset contains data for clean water, sanitation and hygiene.
#
# website from which the data set is taken:
#
# https://ourworldindata.org/explorers/water-and-sanitation?region=Africa&facet=none&Resource=Drinking+water&Level+of+Access=Basic&Residence=Total&Relative+to+population=Share+of+population&country=IND~USA~KEN~OWID_WRL~BGD~ZAF~CHN
#
# And also datasets on deaths due to unsafe water and sanitation:
#
# https://ourworldindata.org/grapher/number-of-deaths-by-risk-factor
# https://ourworldindata.org/grapher/number-of-deaths-by-risk-factor
#
# In addition, total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars):
#
# https://ourworldindata.org/grapher/total-oda-for-water-supply-and-sanitation-by-recipient?tab=chart&region=Asia

# %% [markdown]
# # <div style="color:green;"><b> Let's get started then. !!! </b></div>

# %% [markdown]
# Firstly, we start by importing the libraries we will use.

# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
import plotly.graph_objs as go
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We continue by reading and analyzing our datasets...

# %%
df_wat_san=pd.read_csv('water-and-sanitation.csv')
df_uns_wat = pd.read_csv("share-deaths-unsafe-water.csv")
df_uns_san = pd.read_csv("share-deaths-unsafe-sanitation.csv")
df_sup = pd.read_csv("total-oda-for-water-supply-and-sanitation-by-recipient (1).csv")

# %%
df_wat_san.head()
# Out:
#    Access to improved drinking water  Access to basic drinking water  \
# 0                              31.83                           28.17
# 1                              31.86                           28.20
# 2                              34.19                           30.24
# 3                              36.51                           32.27
# 4                              38.85                           34.33
#
#    Access to limited drinking water  Access to unimproved drinking water  \
# 0                              3.66                                43.18
# 1                              3.66                                43.17
# 2                              3.95                                41.69
# 3                              4.24                                40.21
# 4                              4.52                                38.72
#
#    No access to drinking water  Access to safely managed drinking water  \
# ...

# %%
df_wat_san.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5118 entries, 0 to 5117
# Columns: 118 entries, Access to improved drinking water to hyg_bas_without
# dtypes: float64(116), int64(1), object(1)
# memory usage: 4.6+ MB

# %%
df_uns_wat.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: Age-standardized (Percent)
# 0                                               1.05
# 1                                               1.05
# 2                                               1.07
# 3                                               1.28
# 4                                               1.19

# %%
df_uns_wat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 4 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Entity                                                                                                6840 non-null   object
#  1   Code                                                                                                  6150 non-null   object
#  2   Year                                                                                                  6840 non-null   int64
#  3   Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: Age-standardized (Percent)  6840 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 213.9+ KB

# %%
df_uns_san.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: Age-standardized (Percent)
# 0                                               0.79
# 1                                               0.79
# 2                                               0.81
# 3                                               0.97
# 4                                               0.89

# %%
df_uns_san.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6840 entries, 0 to 6839
# Data columns (total 4 columns):
#  #   Column                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                              --------------  -----
#  0   Entity                                                                                              6840 non-null   object
#  1   Code                                                                                                6150 non-null   object
#  2   Year                                                                                                6840 non-null   int64
#  3   Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: Age-standardized (Percent)  6840 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 213.9+ KB

# %%
df_sup.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  2000
# 1  Afghanistan  AFG  2001
# 2  Afghanistan  AFG  2002
# 3  Afghanistan  AFG  2003
# 4  Afghanistan  AFG  2004
#
#    6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL
# 0                                          4640000.0
# 1                                          1320000.0
# 2                                         13220000.0
# 3                                         25810000.0
# 4                                         41890000.0

# %%
df_sup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3098 entries, 0 to 3097
# Data columns (total 4 columns):
#  #   Column                                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                       --------------  -----
#  0   Entity                                                                                                                                                                                       3098 non-null   object
#  1   Code                                                                                                                                                                                         2888 non-null   object
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# ## With Missingno to check null/missing values

# %%
def calculate_missing_percentage(df):
    missing_values_count = df.isnull().sum()
    total_cells = np.product(df.shape)
    total_missing = missing_values_count.sum()
    missing_percentage = (total_missing/total_cells) * 100
    return missing_percentage

# %%
missing_percentage1 = calculate_missing_percentage(df_wat_san)
missing_percentage2 = calculate_missing_percentage(df_uns_san)
missing_percentage3 = calculate_missing_percentage(df_uns_wat)
missing_percentage4 = calculate_missing_percentage(df_sup)
print("Percentage of missing values in water-and-sanitation.csv:", missing_percentage1)
print("Percentage of missing values in share-deaths-unsafe-sanitation.csv:", missing_percentage2)
print("Percentage of missing values in share-deaths-unsafe-water.csv:", missing_percentage3)
print("Percentage of missing values in total-oda-for-water-supply-and-sanitation.csv:", missing_percentage4)
# Out:
# Percentage of missing values in water-and-sanitation.csv: 35.10243010709957
# Percentage of missing values in share-deaths-unsafe-sanitation.csv: 2.5219298245614032
# Percentage of missing values in share-deaths-unsafe-water.csv: 2.5219298245614032
# Percentage of missing values in total-oda-for-water-supply-and-sanitation.csv: 1.6946417043253712

# %% [markdown]
# ## Why I use the missingno ?

# %% [markdown]
# Since water and sanitation contains too many columns, it is possible to see all columns with this graph

# %%
msno.bar(df_wat_san)
# Out:
# <AxesSubplot: >

# %%
print("--------Percentage of Missing Data in Each Column in The Water and Sanitation Dataset: --------")
(df_wat_san.isna().sum()/len(df_wat_san)*100).apply(lambda x: str(((x*100)//1)/100)+"%")
# Out:
# --------Percentage of Missing Data in Each Column in The Water and Sanitation Dataset: --------
# Access to improved drinking water       0.95%
# Access to basic drinking water          0.95%
# Access to limited drinking water        0.95%
# Access to unimproved drinking water     0.95%
# No access to drinking water             2.75%
#                                         ...
# san_imp_without                         1.46%
# san_bas_without                         1.46%
# san_sm_without                         42.88%
# hyg_bas_number_without                  73.5%
# hyg_bas_without                         73.5%
# Length: 118, dtype: object

# %%
print("--------Percentage of Missing Data in Each Column in The Deaths of Unsafe Water Dataset: --------")
(df_uns_wat.isna().sum()/len(df_uns_wat)*100).apply(lambda x: str(((x*100)//1)/100)+"%")
# Out:
# --------Percentage of Missing Data in Each Column in The Deaths of Unsafe Water Dataset: --------
# Entity                                                                                                    0.0%
# Code                                                                                                    10.08%
# Year                                                                                                      0.0%
# Deaths - Cause: All causes - Risk: Unsafe water source - Sex: Both - Age: Age-standardized (Percent)      0.0%
# dtype: object

# %%
print("--------Percentage of Missing Data in Each Column in The Deaths of Unsafe Sanitation Dataset: --------")
(df_uns_san.isna().sum()/len(df_uns_san)*100).apply(lambda x: str(((x*100)//1)/100)+"%")
# Out:
# --------Percentage of Missing Data in Each Column in The Deaths of Unsafe Sanitation Dataset: --------
# Entity                                                                                                  0.0%
# Code                                                                                                  10.08%
# Year                                                                                                    0.0%
# Deaths - Cause: All causes - Risk: Unsafe sanitation - Sex: Both - Age: Age-standardized (Percent)      0.0%
# dtype: object

# %%
print("--------Percentage of Missing Data in Each Column in The Total ODA: --------")
(df_sup.isna().sum()/len(df_sup)*100).apply(lambda x: str(((x*100)//1)/100)+"%")
# Out:
# --------Percentage of Missing Data in Each Column in The Total ODA: --------
# Entity                                                                                                                                                                                          0.0%
# Code                                                                                                                                                                                           6.77%
# Year                                                                                                                                                                                            0.0%
# 6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL     0.0%
# dtype: object

# %%
df_Morocco = df_sup[df_sup['Entity'] == 'Morocco']
df_India = df_sup[df_sup['Entity'] == 'India']
df_ser = df_sup[df_sup['Entity'] == 'Serbia']

plt.plot(df_Morocco['Year'], df_Morocco['6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL'], color='g', label='Morocco')
plt.plot(df_India['Year'], df_India['6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL'], color='r', label='India')
plt.plot(df_ser['Year'], df_ser['6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL'], color='b', label='Serbia')

plt.title('Total Official Financial Flows for Water Supply and Sanitation, by Recipient')
plt.xlabel('Year')
plt.ylabel('Millions dollar')
plt.xticks(range(df_Morocco['Year'].min(), df_Morocco['Year'].max()+1, 2))

plt.legend()
plt.show()

# %%
df_wat_san_Mor = df_wat_san[df_wat_san['Entity'] == 'Morocco']
df_wat_san_Ind = df_wat_san[df_wat_san['Entity'] == 'India']
df_wat_san_Ser = df_wat_san[df_wat_san['Entity'] == 'Serbia']
df_wat_san_hg = df_wat_san[df_wat_san['Entity'] == 'High income']
df_wat_san_low = df_wat_san[df_wat_san['Entity'] == 'Low income']
df_wat_san_west = df_wat_san[df_wat_san['Entity'] == 'Western Asia and Northern Africa']

# %%
sdg_regions = [df_wat_san_Mor,df_wat_san_low, df_wat_san_Ind,df_wat_san_west, df_wat_san_Ser,df_wat_san_hg]
sdg_region_title = ['Morocco', 
                    'Low Income',
                   'India',
                   'Western Asia and Northern Africa', 
                   'Serbia',
                   'High income']
index = 0
for region in sdg_regions: 
    title = sdg_region_title[index]
    x = region['Year']
    y2 = region['Access to improved drinking water']
    y3 = region['Access to unimproved drinking water']
    y4 = region['No access to drinking water']
    colors=['#FF9070','#FCD17A','#4CC4E7']
        
    y = np.vstack([y2,y3,y4])

    labels = ["Improved service", "Unimproved", "Surface water"]
    fig, ax = plt.subplots()
    ax.stackplot(x,y2,y3,y4, labels=labels, colors=colors)
    plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
    plt.xticks(range(2000,2020,16))
    plt.xlabel('Year')
    plt.ylabel('Percent Coverage')
    plt.title(title)
    plt.show()
    index += 1

# %%
countries = ["Morocco", "Algeria","Tunisia", "Libya", "Egypt", 
             "Sudan, ""Eritrea", "Ethiopia", "Djibouti", "Somalia", 
             "Kenya", "Uganda", "Tanzania", "Rwanda", "Mozambique", 
             "Comoros", "Malawi", "Zambia", "South Africa", "Bostwana", 
             "Namibia", "Lesotho", "Angola", "Democratic Republic of Congo", 
             "Congo", "Gabon", "Cameroon", "Central Afrikan Republic", "Chad", 
             "Nigeria", "Benin", "Togo", "Ghana", "Burkina Faso", "Cote d'Ivoire", 
             "Liberia", "Sierra Leone", "Guinea", "Mali", "Senegal", "Guinea-Bissau",
             "Mauritania", "Niger", "South Sudan", "Burundi", "Madagascar", "Sub-Saharan Africa" ]
selected_data = df_sup[df_sup["Entity"].isin(countries)]

columns = ["6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL", "Year", "Entity"]
selected_data = selected_data[columns]

# %%
sdg_regions = [df_wat_san_Mor,df_wat_san_low, df_wat_san_Ind,df_wat_san_west, df_wat_san_Ser,df_wat_san_hg]
sdg_region_title = ['Morocco', 
                    'Low Income',
                   'India',
                   'Western Asia and Northern Africa', 
                   'Serbia',
                   'High income',]
index = 0
for region in sdg_regions: 
        title = sdg_region_title[index]
        
        plt.plot(region['Year'], region['Access to improved sanitation'], fillstyle = 'full', color = 'yellowgreen', marker = '.', label = "improved sanitation")
        plt.plot(region['Year'], region['Access to unimproved sanitation facilities'],fillstyle = 'full', color = 'mediumpurple', marker ='.', label = 'Unimproved sanitation')
        
        plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8), shadow=True, ncol=1)
        plt.xticks(range(2000,2017,16))
        plt.xlabel('Year')
        plt.ylabel('Percent Coverage')
        plt.title(title)
        plt.show()
        
        image_title =  'Plot of Water Service Levels Across the world'
        
        index += 1

# %%
import matplotlib.ticker as ticker

sum = selected_data.groupby('Entity')['6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL'].sum()

ax = sum.plot(kind='bar')
ax.bar(sum.index, sum.values, align='center', width=0.2)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.xticks(rotation=87)
plt.xlabel('Country')
plt.ylabel('Total official financial flow (constant 2020 USD)')
plt.title('Total official financial flow by Country')
plt.show()

# %% [markdown]
# Serbia has 7,486.2424 million inhabitants out of a population of 7,516 million and has provided improved water to 7,486.2424 million inhabitants, likewise European countries also have high rates of improvement.

# %% [markdown]
# * The two countries that receive the most aid in the African region are Egypt and Morocco
#
# *  In 2020, Egypt reached 27,186,660 people with improved drinking water, which is 95.12% of its population. In the same year, 99% of its population had access to improved water sources

# %%
df_wat_san_low.groupby('Year')["Access to improved drinking water",  
                           "Access to unimproved drinking water", "No access to drinking water"].mean().plot(kind='bar', figsize=(25, 8), color=['blue', 'green', 'orange', 'red', 'purple', 'yellow'])
plt.suptitle('Average Water Availability in Low-income Countries by Year', fontsize=15)
plt.ylabel('Population')
plt.xlabel('Year')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_608\2744799522.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_wat_san_low.groupby('Year')["Access to improved drinking water",
# Text(0.5, 0, 'Year')

# %%
europe_countries = ['Albania', 'Austria', 'Belgium', 'Bosnia and Herzegovina',  
                    'Bulgaria', 'Croatia', 'Czech Republic', 'Denmark', 'Estonia',
                    'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland',
                    'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Montenegro', 'Netherlands',
                    'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia', 'Slovak Republic',
                    'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey', 'United Kingdom']
selected_data_eu = df_sup[df_sup["Entity"].isin(europe_countries)]

columns = ["6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL", "Year", "Entity"]
selected_data_eu = selected_data_eu[columns]

# %%
sum = selected_data_eu.groupby('Entity')['6.a.1 - Total official development assistance (gross disbursement) for water supply and sanitation, by recipient countries (millions of constant 2020 United States dollars) - DC_TOF_WASHL'].sum()

ax = sum.plot(kind='bar')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('Country')
plt.ylabel('Total official financial flow  (constant 2020 USD)')
plt.title('Total official financial flow by Country')
plt.show()

# %%
df_wat_san_world = df_wat_san[df_wat_san['Entity'] == 'World']

# %%
df_wat_san_world.groupby('Year')["Access to improved drinking water",  
                           "Access to unimproved drinking water", "No access to drinking water"].mean().plot(kind='bar', figsize=(25, 8), color=['blue', 'green', 'orange', 'red', 'purple', 'yellow'])
plt.suptitle('Average Water Availability in the World by Year', fontsize=15)
plt.ylabel('Population')
plt.xlabel('Year')
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_608\1602800587.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_wat_san_world.groupby('Year')["Access to improved drinking water",
# Text(0.5, 0, 'Year')
